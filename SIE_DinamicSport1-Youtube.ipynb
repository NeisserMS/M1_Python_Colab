# %% [markdown]
# <a href="https://colab.research.google.com/github/NeisserMS/M1_Python_Colab/blob/main/SIE_DinamicSport1-Youtube.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #### Afinando nuestro DataSet Crudo  y transformarlo en un DataSet Refinado

# %%
import pandas as pd

# %%
print(pd.__version__)
# Out:
# 1.1.5

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-e7b72401-f5d2-4eb5-88bb-5da9584dd538" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e7b72401-f5d2-4eb5-88bb-5da9584dd538">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving DataSet.xls to DataSet (1).xls

# %%
import io
dfxls = pd.read_excel(io.BytesIO(uploaded['DataSet.xls']))
dfxls
# Out:
#      id_Venta                     Nombre  ... nombre_cliente       dni
# 0           1  Casaca Crop Impermeable M  ...           Jair  10000000
# 1           2  Casaca Crop Impermeable M  ...          Karen  10000001
# 2           3                Jean Basico  ...         Junior  10000002
# 3           4    Shompa tejida valentina  ...         Martha  10000003
# 4           5   Blusa manga larga Urbano  ...        Mariano  10000004
# ..        ...                        ...  ...            ...       ...
# 495       496               Poleron Vero  ...        Neisser  10000491
# 496       497             Chompa newport  ...       Katyuska  10000492
# 497       498         Leggings deportivo  ...          Karla  10000486
# 498       499               Poleron Vero  ...           Dani  10000486
# 499       500               Poleron Vero  ...         Thiago  10000486
#
# [500 rows x 11 columns]

# %%
url = ("https://raw.githubusercontent.com/NeisserMS/M1_Python_Colab/main/DataSetNulox.csv")
df = pd.read_csv(url, sep=';')
df.head((40))
# Out:
#     id_Venta                     Nombre  ... nombre_cliente         dni
# 0        1.0  Casaca Crop Impermeable M  ...           Jair  10000000.0
# 1        NaN  Casaca Crop Impermeable M  ...          Karen  10000001.0
# 2        3.0                        NaN  ...         Junior  10000002.0
# 3        4.0    Shompa tejida valentina  ...         Martha  10000003.0
# 4        5.0   Blusa manga larga Urbano  ...        Mariano  10000004.0
# 5        6.0             Chompa newport  ...         Keyler  10000005.0
# 6        7.0         Leggings deportivo  ...          Jordi  10000006.0
# 7        8.0               Poleron Vero  ...        Segundo  10000007.0
# 8        9.0               Short Urbano  ...      Magdalena  10000008.0
# 9       10.0            Polo manga cero  ...            NaN  10000009.0
# 10      11.0            Pantalon Urbano  ...         Arimar         NaN
# 11      12.0              Blusa Cottons  ...        Neisser  10000011.0
# ...

# %%
dfNuevo = df.dropna()
dfNuevo
# Out:
#      id_Venta                     Nombre  ... nombre_cliente         dni
# 0         1.0  Casaca Crop Impermeable M  ...           Jair  10000000.0
# 11       12.0              Blusa Cottons  ...        Neisser  10000011.0
# 12       13.0  Casaca Crop Impermeable M  ...          Kevin  10000012.0
# 13       14.0  Casaca Crop Impermeable M  ...         Daniel  10000013.0
# 14       15.0                Jean Basico  ...         Dayana  10000014.0
# ..        ...                        ...  ...            ...         ...
# 495     496.0               Poleron Vero  ...        Neisser  10000491.0
# 496     497.0             Chompa newport  ...       Katyuska  10000492.0
# 497     498.0         Leggings deportivo  ...          Karla  10000486.0
# 498     499.0               Poleron Vero  ...           Dani  10000486.0
# 499     500.0               Poleron Vero  ...         Thiago  10000486.0
#
# [490 rows x 11 columns]

# %%
df
# Out:
#      id_Venta                     Nombre  ... nombre_cliente         dni
# 0         1.0  Casaca Crop Impermeable M  ...           Jair  10000000.0
# 1         NaN  Casaca Crop Impermeable M  ...          Karen  10000001.0
# 2         3.0                        NaN  ...         Junior  10000002.0
# 3         4.0    Shompa tejida valentina  ...         Martha  10000003.0
# 4         5.0   Blusa manga larga Urbano  ...        Mariano  10000004.0
# ..        ...                        ...  ...            ...         ...
# 495     496.0               Poleron Vero  ...        Neisser  10000491.0
# 496     497.0             Chompa newport  ...       Katyuska  10000492.0
# 497     498.0         Leggings deportivo  ...          Karla  10000486.0
# 498     499.0               Poleron Vero  ...           Dani  10000486.0
# 499     500.0               Poleron Vero  ...         Thiago  10000486.0
#
# [500 rows x 11 columns]

# %%
df.dropna(inplace = True)
df
# Out:
#      id_Venta                     Nombre  ... nombre_cliente         dni
# 0         1.0  Casaca Crop Impermeable M  ...           Jair  10000000.0
# 11       12.0              Blusa Cottons  ...        Neisser  10000011.0
# 12       13.0  Casaca Crop Impermeable M  ...          Kevin  10000012.0
# 13       14.0  Casaca Crop Impermeable M  ...         Daniel  10000013.0
# 14       15.0                Jean Basico  ...         Dayana  10000014.0
# ..        ...                        ...  ...            ...         ...
# 495     496.0               Poleron Vero  ...        Neisser  10000491.0
# 496     497.0             Chompa newport  ...       Katyuska  10000492.0
# 497     498.0         Leggings deportivo  ...          Karla  10000486.0
# 498     499.0               Poleron Vero  ...           Dani  10000486.0
# 499     500.0               Poleron Vero  ...         Thiago  10000486.0
#
# [490 rows x 11 columns]

# %%
url = ("https://raw.githubusercontent.com/NeisserMS/M1_Python_Colab/main/DataSetNulox.csv")
Dframe = pd.read_csv(url, sep=';')
Dframe.head((40))
# Out:
#     id_Venta                     Nombre  ... nombre_cliente         dni
# 0        1.0  Casaca Crop Impermeable M  ...           Jair  10000000.0
# 1        NaN  Casaca Crop Impermeable M  ...          Karen  10000001.0
# 2        3.0                        NaN  ...         Junior  10000002.0
# 3        4.0    Shompa tejida valentina  ...         Martha  10000003.0
# 4        5.0   Blusa manga larga Urbano  ...        Mariano  10000004.0
# 5        6.0             Chompa newport  ...         Keyler  10000005.0
# 6        7.0         Leggings deportivo  ...          Jordi  10000006.0
# 7        8.0               Poleron Vero  ...        Segundo  10000007.0
# 8        9.0               Short Urbano  ...      Magdalena  10000008.0
# 9       10.0            Polo manga cero  ...            NaN  10000009.0
# 10      11.0            Pantalon Urbano  ...         Arimar         NaN
# 11      12.0              Blusa Cottons  ...        Neisser  10000011.0
# ...

# %%
Dframe.fillna(333, inplace=True)
Dframe
# Out:
#      id_Venta                     Nombre  ... nombre_cliente         dni
# 0         1.0  Casaca Crop Impermeable M  ...           Jair  10000000.0
# 1       333.0  Casaca Crop Impermeable M  ...          Karen  10000001.0
# 2         3.0                        333  ...         Junior  10000002.0
# 3         4.0    Shompa tejida valentina  ...         Martha  10000003.0
# 4         5.0   Blusa manga larga Urbano  ...        Mariano  10000004.0
# ..        ...                        ...  ...            ...         ...
# 495     496.0               Poleron Vero  ...        Neisser  10000491.0
# 496     497.0             Chompa newport  ...       Katyuska  10000492.0
# 497     498.0         Leggings deportivo  ...          Karla  10000486.0
# 498     499.0               Poleron Vero  ...           Dani  10000486.0
# 499     500.0               Poleron Vero  ...         Thiago  10000486.0
#
# [500 rows x 11 columns]

# %% [markdown]
# #### Media, Mediana y Moda

# %%
url = ("https://raw.githubusercontent.com/NeisserMS/M1_Python_Colab/main/DataSetNulox.csv")
Dframe = pd.read_csv(url, sep=';')
Dframe.head((40))
# Out:
#     id_Venta                     Nombre  ... nombre_cliente         dni
# 0        1.0  Casaca Crop Impermeable M  ...           Jair  10000000.0
# 1        NaN  Casaca Crop Impermeable M  ...          Karen  10000001.0
# 2        3.0                        NaN  ...         Junior  10000002.0
# 3        4.0    Shompa tejida valentina  ...         Martha  10000003.0
# 4        5.0   Blusa manga larga Urbano  ...        Mariano  10000004.0
# 5        6.0             Chompa newport  ...         Keyler  10000005.0
# 6        7.0         Leggings deportivo  ...          Jordi  10000006.0
# 7        8.0               Poleron Vero  ...        Segundo  10000007.0
# 8        9.0               Short Urbano  ...      Magdalena  10000008.0
# 9       10.0            Polo manga cero  ...            NaN  10000009.0
# 10      11.0            Pantalon Urbano  ...         Arimar         NaN
# 11      12.0              Blusa Cottons  ...        Neisser  10000011.0
# ...

# %%
media = Dframe['Precio'].mean()
media
# Out:
# 37.97595190380761

# %%
Dframe['Precio'].fillna(38, inplace = True)
Dframe
# Out:
#      id_Venta                     Nombre  ... nombre_cliente         dni
# 0         1.0  Casaca Crop Impermeable M  ...           Jair  10000000.0
# 1         NaN  Casaca Crop Impermeable M  ...          Karen  10000001.0
# 2         3.0                        NaN  ...         Junior  10000002.0
# 3         4.0    Shompa tejida valentina  ...         Martha  10000003.0
# 4         5.0   Blusa manga larga Urbano  ...        Mariano  10000004.0
# ..        ...                        ...  ...            ...         ...
# 495     496.0               Poleron Vero  ...        Neisser  10000491.0
# 496     497.0             Chompa newport  ...       Katyuska  10000492.0
# 497     498.0         Leggings deportivo  ...          Karla  10000486.0
# 498     499.0               Poleron Vero  ...           Dani  10000486.0
# 499     500.0               Poleron Vero  ...         Thiago  10000486.0
#
# [500 rows x 11 columns]

# %%
mediana = Dframe['Precio'].mode()
mediana
# Out:
# 0    20.0
# dtype: float64

# %%
mode = Dframe['Precio'].mode()
mode
# Out:
# 0    20.0
# dtype: float64

# %%
url = ("https://raw.githubusercontent.com/NeisserMS/M1_Python_Colab/main/DataSet-DinamicSport.csv")
Dframe = pd.read_csv(url, sep=';')
Dframe.head((40))
# Out:
#    id_Venta                     Nombre  ... nombre_cliente       dni
# 0       uno  Casaca Crop Impermeable M  ...           Jair  10000000
# 1       200  Casaca Crop Impermeable M  ...          Karen  10000001
# 2         3                Jean Basico  ...         Junior  10000002
# 3         3                Jean Basico  ...         Junior  10000002
# 4         5   Blusa manga larga Urbano  ...        Mariano  10000004
# 5         6                  Jean Nort  ...          Marie  10000005
# 6         7         Leggings deportivo  ...          Jordi  10000006
# 7         8               Poleron Vero  ...        Segundo  10000007
# 8         9               Short Urbano  ...      Magdalena  10000008
# 9        10            Polo manga cero  ...          Jessy  10000009
# 10       11            Pantalon Urbano  ...         Arimar  10000010
# 11       12              Blusa Cottons  ...        Neisser  10000011
# 12       13  Casaca Crop Impermeable M  ...          Kevin  10000012
# ...

# %%
Dframe.id_Venta[Dframe.id_Venta=='uno']=1
Dframe
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#     id_Venta                     Nombre  ... nombre_cliente       dni
# 0          1  Casaca Crop Impermeable M  ...           Jair  10000000
# 1        200  Casaca Crop Impermeable M  ...          Karen  10000001
# 2          3                Jean Basico  ...         Junior  10000002
# 3          3                Jean Basico  ...         Junior  10000002
# 4          5   Blusa manga larga Urbano  ...        Mariano  10000004
# ..       ...                        ...  ...            ...       ...
# 495      496               Poleron Vero  ...        Neisser  10000491
# ...

# %%
Dframe.loc[1,'id_Venta'] = 2
Dframe
# Out:
#     id_Venta                     Nombre  ... nombre_cliente       dni
# 0          1  Casaca Crop Impermeable M  ...           Jair  10000000
# 1          2  Casaca Crop Impermeable M  ...          Karen  10000001
# 2          3                Jean Basico  ...         Junior  10000002
# 3          3                Jean Basico  ...         Junior  10000002
# 4          5   Blusa manga larga Urbano  ...        Mariano  10000004
# ..       ...                        ...  ...            ...       ...
# 495      496               Poleron Vero  ...        Neisser  10000491
# 496      497             Chompa newport  ...       Katyuska  10000492
# 497      498         Leggings deportivo  ...          Karla  10000486
# 498      499               Poleron Vero  ...           Dani  10000486
# 499      500               Poleron Vero  ...         Thiago  10000486
#
# [500 rows x 11 columns]

# %%
Dframe.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 495    False
# 496    False
# 497    False
# 498    False
# 499    False
# Length: 500, dtype: bool

# %%
url = ("https://raw.githubusercontent.com/NeisserMS/M1_Python_Colab/main/DataSet-DinamicSport.csv")
Dframe = pd.read_csv(url, sep=';')
Dframe.head((40))
# Out:
#    id_Venta                     Nombre  ... nombre_cliente       dni
# 0       uno  Casaca Crop Impermeable M  ...           Jair  10000000
# 1       200  Casaca Crop Impermeable M  ...          Karen  10000001
# 2         3                Jean Basico  ...         Junior  10000002
# 3         3                Jean Basico  ...         Junior  10000002
# 4         5   Blusa manga larga Urbano  ...        Mariano  10000004
# 5         6                  Jean Nort  ...          Marie  10000005
# 6         7         Leggings deportivo  ...          Jordi  10000006
# 7         8               Poleron Vero  ...        Segundo  10000007
# 8         9               Short Urbano  ...      Magdalena  10000008
# 9        10            Polo manga cero  ...          Jessy  10000009
# 10       11            Pantalon Urbano  ...         Arimar  10000010
# 11       12              Blusa Cottons  ...        Neisser  10000011
# 12       13  Casaca Crop Impermeable M  ...          Kevin  10000012
# ...

# %%
Dframe.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3       True
# 4      False
#        ...
# 495    False
# 496    False
# 497    False
# 498    False
# 499    False
# Length: 500, dtype: bool

# %%
Dframe.drop_duplicates(inplace = True)
Dframe
# Out:
#     id_Venta                     Nombre  ... nombre_cliente       dni
# 0        uno  Casaca Crop Impermeable M  ...           Jair  10000000
# 1        200  Casaca Crop Impermeable M  ...          Karen  10000001
# 2          3                Jean Basico  ...         Junior  10000002
# 4          5   Blusa manga larga Urbano  ...        Mariano  10000004
# 5          6                  Jean Nort  ...          Marie  10000005
# ..       ...                        ...  ...            ...       ...
# 495      496               Poleron Vero  ...        Neisser  10000491
# 496      497             Chompa newport  ...       Katyuska  10000492
# 497      498         Leggings deportivo  ...          Karla  10000486
# 498      499               Poleron Vero  ...           Dani  10000486
# 499      500               Poleron Vero  ...         Thiago  10000486
#
# [499 rows x 11 columns]
